# %% [markdown]
# ***Importing libraries***

# %%
import urllib.request
from bs4 import BeautifulSoup
import time
from fake_useragent import UserAgent
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Scraping the links of cars from each page

# %% [markdown]
# ***Main links for iteration***

# %%
url1 = "https://kolesa.kz"

url2_alm = "https://kolesa.kz/cars/region-almatinskaya-oblast/?page={}" #For Almaty state we gathered 1500 links
url3_alm = "https://kolesa.kz/cars/region-almatinskaya-oblast"

url2_akm = "https://kolesa.kz/cars/region-akmolinskaya-oblast/?page={}" #For Akmola st. 500
url3_akm = "https://kolesa.kz/cars/region-akmolinskaya-oblast/"

url2_man = "https://kolesa.kz/cars/region-mangistauskaya-oblast/?page={}" #For Mangistau st. 150
url3_man = "https://kolesa.kz/cars/region-mangistauskaya-oblast/"

url2_vos = "https://kolesa.kz/cars/region-vostochnokazakhstanskaya-oblast/?page={}" #For East Kaz st. 250

# %% [markdown]
# ***How does iteraion process of obtaining links of cars from each page look like?***

# %%
request = urllib.request.Request("https://kolesa.kz/cars/region-almatinskaya-oblast/?page=2")
source = urllib.request.urlopen(request, timeout=8.5).read()
soup = BeautifulSoup(source, features="html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ru" xmlns:xlink="http://www.w3.org/1999/xlink">
# <head>
# <meta charset="utf-8"/>
# <!--SEO-->
# <title>Купить автомобиль в Алматинской области. Продажа машин в Алматинской области — Колёса, страница 2</title>
# <meta content="Колёса - бесплатные объявления о продаже и покупке БУ автомобилей в Алматинской области. Лучшие предложения с ценами в Алматинской области. Авторынок подержанных автомобилей | Страница 2" name="description">
# <meta content="купить, автомобиль, алматинской, области, продажа, машин, колёса" name="keywords"/>
# <meta content="487915631223232" property="fb:pages"/>
# <meta content="3a6b5a2f06b43bce" name="yandex-verification"/>
# <link href="//m.kolesa.kz/cars/region-almatinskaya-oblast/?page=2" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://kolesa.kz/cars/region-almatinskaya-oblast/" rel="canonical">
# <meta content="69476cf770e74b47e29b023e1eedfdb9" name="wmail-verification"/>
# <!--SEO-->
# <meta content="Kolesa" name="author"/>
# <link href="//kolesa.kz/static/frontend/css/main-payment.db3e86a1a1.css" rel="stylesheet" type="text/css"/>
# <link href="//kolesa.kz/static/frontend/css/main-common.87a9c6188e.css" rel="stylesheet" type="text/css"/>
# <link href="//kolesa.kz/static/frontend/css/main-index.b7be1ff82f.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?v=2" rel="icon" sizes="any"/>
# <link href="/icon.svg?v=2" rel="icon" type="image/svg+xml"/>
# <link href="/apple-touch-icon.png?v=2" rel="apple-touch-icon"/>
# <link href="/manifest.webmanifest?v=2" rel="manifest"/>
# <meta content="Kolesa.kz" name="apple-mobile-web-app-title"/>
# <meta content="Kolesa.kz" name="application-name"/>
# <meta content="#ffffff" name="theme-color"/>
# <script type="text/javascript">
#         var YaDirectParams = {
#             stat_id: 1,
#             ad_format: "direct",
#             font_size: 1,
#             type: "oldHorizontal",
#             limit: 1,
#             title_font_size: 3,
#             links_underline: true,
#             site_bg_color: "FFFFFF",
#             bg_color: "FFF2CF",
#             title_color: "996633",
#             url_color: "0000CC",
#             text_color: "333333",
#             hover_color: "0066FF",
#             favicon: true,
#             no_sitelinks: true
#         };
#     </script>
# <meta content="https://kolesa.kz/static/frontend/images/og-image.jpg" property="og:image">
# <script>
#     loadErrorsMap = [];
#     loadErrorHandler = function(node) {
#         loadErrorsMap.push(node);
#     }
# </script>
# <link as="font" crossorigin="anonymous" href="https://kolesa.kz/static/frontend/fonts/OpenSans-Regular.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="anonymous" href="https://kolesa.kz/static/frontend/fonts/OpenSans-Semibold.woff2" rel="preload" type="font/woff2"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});
# var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
# j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-M6NQ9S');</script>
# <script>
#     window.dataLayer = window.dataLayer || [];
#     window.gtag = function () { dataLayer.push(arguments); }
#
#     window.gtag('js', new Date());
#     window.gtag('config', 'G-K434WRXPFF');
# </script>
# <!-- End Google Tag Manager -->
# <!-- TikTok Pixel -->
# <script>
#     !function (w, d, t) {
#         w.TiktokAnalyticsObject=t;var ttq=w[t]=w[t]||[];ttq.methods=["page","track","identify","instances","debug","on","off","once","ready","alias","group","enableCookie","disableCookie"],ttq.setAndDefer=function(t,e){t[e]=function(){t.push([e].concat(Array.prototype.slice.call(arguments,0)))}};for(var i=0;i<ttq.methods.length;i++)ttq.setAndDefer(ttq,ttq.methods[i]);ttq.instance=function(t){for(var e=ttq._i[t]||[],n=0;n<ttq.methods.length;n++
#         )ttq.setAndDefer(e,ttq.methods[n]);return e},ttq.load=function(e,n){var i="https://analytics.tiktok.com/i18n/pixel/events.js";ttq._i=ttq._i||{},ttq._i[e]=[],ttq._i[e]._u=i,ttq._t=ttq._t||{},ttq._t[e]=+new Date,ttq._o=ttq._o||{},ttq._o[e]=n||{};n=document.createElement("script");n.type="text/javascript",n.async=!0,n.src=i+"?sdkid="+e+"&lib="+t;e=document.getElementsByTagName("script")[0];e.parentNode.insertBefore(n,e)};
#
#         ttq.load('CBCFH3RC77U9CRRSGTL0');
#         ttq.page();
#     }(window, document, 'ttq');
# </script>
# <!-- End TikTok Pixel -->
# <script>
#     var listing = {
#         items: [],
#         vip: [],
#         grid: [],
#         hot: [],
#     };
# </script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     window.googletag = window.googletag || { cmd: [] };
#
#     googletag.cmd.push(function () {
#         // Скрываем баннеры если в них не появился контент.
#         var iterations = 0;
#         var interval = window.setInterval(function () {
#             try {
#                 var elements = document.querySelectorAll('.common-b');
#
#                 if (elements.length < 1 || ++iterations > 100) {
#                     window.clearInterval(interval);
#                 }
#
#                 elements.forEach(function (node) {
#
#                         if (!node.children[0]) {
#                             node.style.display = "none";
#
#                             return;
#                         }
#
#                         node.style.display = window.getComputedStyle(node.children[0]).display === 'none' ? 'none' : undefined;
#                 });
#             } catch (e) {
#                 clearInterval(interval);
#             }
#         }, 50);
#     });
# </script>
# <script>
#     window.googletag = window.googletag || { cmd: [] };
#
#     googletag.cmd.push(function() {
#                     googletag.defineSlot('/21685517069/Kolesa_Cars_Leaderboard_new', [[468,60],[550,80],[728,90]], 'div-gpt-ad-1521018919546-0')
#                 .addService(googletag.pubads());
#                     googletag.defineSlot('/21685517069/Kolesa_Cars_Right_new', [[240,400],[300,250],[336,280],[300,600]], 'div-gpt-ad-1521019144758-0')
#                 .addService(googletag.pubads());
#
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#
#                     googletag.pubads().setTargeting('kl_category', 'Машины');
#                     googletag.pubads().setTargeting('kl_url', '/cars/region-almatinskaya-oblast/?page=2');
#
#         googletag.enableServices();
#     });
# </script>
# </meta></link></meta></head>
# <body class="">
# <script>
#     var data = {"isProduction":true,"auth-url":"\/user\/ajax-xdm-auth\/","appHost":"\/\/app.kolesa.kz","views":{"link":"\/ms\/views\/kolesa"},"language":"ru","selectLanguage":{"enabled":true,"current":"ru","alias":"ru","languages":{"kz":"\u049a\u0430\u0437\u0430\u049b\u0448\u0430","ru":"\u0420\u0443\u0441\u0441\u043a\u0438\u0439"},"pageUrl":"\/cars\/region-almatinskaya-oblast\/?page=2"},"staticLink":"\/\/kolesa.kz\/static\/frontend","cdn":{"cookie":"kl_cdn_host","defaultHost":"photos-kl.kcdn.kz"},"limitValues":5,"multiSelectDelimiter":",","sizeNotifications":5,"isCreditPage":false,"isResalePage":false,"hasVerifiedPhone":false,"globalUserId":null,"listedUsersToReport":[18949883],"isNYEnabled":false,"buckyConfig":{"host":"\/ms\/rum","aggregationInterval":100,"sample":1},"buckyPrefix":"kolesa.frontend","sentryConfig":{"isEnabled":true,"blackList":"metrika,Non-Error promise rejection,partner-code-bundles,pcode,AdSDK,gtm.js,Invalid scheme,chrome-extension,anonymous,ntp is not defined,pubads,pagead,freed script,adfox,illegal character,Script error,Invalid scheme,Script error.,"},"advisory":{"url":"\/a\/ajax-advisory\/","timeoutSeconds":5,"cookieName":"promo_advisory_new","cookieDeclineTimeout":86400,"cookieApplyTimeout":86400},"guideHints":{"url":"\/ajax-get-guide-hints\/","cookiePrefix":"gh_"},"accountFill":{"url":"https:\/\/pay.kolesa.kz\/cabinet?"},"urlToSettings":"\/passport\/settings\/","gatewayScript":["https:\/\/pay.kolesa.kz\/static\/js\/gateway\/common\/iframe-loader.js"],"paidServicesUrls":{"move-to-archive":"\/my\/ajax-move-to-archive\/"},"convert":[],"priceHint":{"1":[{"to":5000},{"from":5000,"to":10000},{"from":10000,"to":15000}],"2":[{"to":"1 000 000","text":"\u0434\u043e&nbsp;1&nbsp;\u043c\u043b\u043d"},{"from":"1 000 000","to":"2 000 000","text":"1&nbsp;\u2014&nbsp;2&nbsp;\u043c\u043b\u043d"},{"from":"2 000 000","to":"3 000 000","text":"2&nbsp;\u2014&nbsp;3&nbsp;\u043c\u043b\u043d"}],"3":[{"to":5000},{"from":5000,"to":10000},{"from":10000,"to":15000}],"4":[{"to":300000},{"from":300000,"to":600000},{"from":600000,"to":900000}]},"category":{"id":2,"alias":"cars","name":"auto.car","isSpare":false},"sectionName":"\u041c\u0430\u0448\u0438\u043d\u044b","categoryName":"\u041b\u0435\u0433\u043a\u043e\u0432\u044b\u0435","urlMaskSort":"\/cars\/region-almatinskaya-oblast\/?{%sort}","parameters":{"auto.car.mm":[0,0,0],"regionAlias":"region-almatinskaya-oblast","equipment":""},"scrollToListing":false,"nps":{"project":"kolesa.kz","data":{"category":"\u041b\u0435\u0433\u043a\u043e\u0432\u044b\u0435","section":"\u041c\u0430\u0448\u0438\u043d\u044b"},"url":"https:\/\/kolesa.kz\/ms\/nps\/"},"userLogin":null,"route":"advert:search","controller":"advert","action":"search","app":"Frontend","userId":0};
# </script>
# <div class="layout">
# <div class="layout__content">
# <header>
# <div class="top-header">
# <div class="ui-container">
# <div class="top-header__wrap">
# <ul class="corp-projects">
# <li class="corp-projects__item corp-projects__item--active">
# <a class="corp-projects__title js__tippy corp-projects__link" data-tippy-content="Автомобили" data-tippy-offset="[0, 16]" data-tippy-placement="bottom" data-tippy-theme="kl-dark" href="/">
#                 Kolesa.kz
#             </a>
# </li>
# <li class="corp-projects__item">
# <a class="corp-projects__title js__tippy corp-projects__link" data-tippy-content="Недвижимость" data-tippy-offset="[0, 16]" data-tippy-placement="bottom" data-tippy-theme="kl-dark" href="http://krisha.kz">
#                 Krisha.kz
#             </a>
# </li>
# </ul>
# <nav class="header-menu js__header-menu">
# <ul class="header-menu__list js-header-nav">
# <li class="header-menu__list-item header-menu__list-item--locale">
# <div class="header-menu-dropdown">
# <button class="header-menu-dropdown__toggler js__locale-menu" data-tippy-offset="[0,8]" data-tippy-placement="bottom" data-tippy-template="locale-menu" data-tippy-theme="kl-full">
#                         RU
#                         <span class="header-menu-dropdown__toggler-icon">
# <span class="fi-arrow-mini"></span>
# </span>
# </button>
# <template id="locale-menu">
# <ul class="locale-menu">
# <li class="locale-menu__item">
# <a class="locale-menu__link" href="/language/?backUrl=%2Fcars%2Fregion-almatinskaya-oblast%2F%3Fpage%3D2&amp;language=kz" rel="nofollow">
#                 Қазақша
#             </a>
# </li>
# <li class="locale-menu__item">
# <a class="locale-menu__link locale-menu__link--active" href="/language/?backUrl=%2Fcars%2Fregion-almatinskaya-oblast%2F%3Fpage%3D2&amp;language=ru" rel="nofollow">
#                 Русский
#             </a>
# </li>
# </ul>
# </template>
# </div>
# </li>
# <li class="header-menu__list-item">
# <a class="header-menu-link" href="/passport/register/">
# <span class="header-menu-link__label">Регистрация</span>
# </a>
# </li>
# <li class="header-menu__list-item">
# <a class="header-menu-link" href="/cabinet/">
# <span class="header-menu-link__label">Личный кабинет</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# <div class="main-header">
# <div class="ui-container">
# <div class="main-header__wrap">
# <div class="main-header__logo">
# <div class="main-logo">
# <a class="main-logo__link" href="/">
# <img alt="Колеса" src="//kolesa.kz/static/frontend/images/kolesa-logo-new.svg" width="162"/>
# </a>
# </div>
# </div>
# <div class="main-header__menu">
# <ul class="main-menu" data-test="main-menu">
# <li class="main-menu__item is-active">
# <a class="main-menu__link isSelected" href="/" id="currentSection">
# <span class="main-menu__label">Машины</span>
# </a>
# </li>
# <li class="main-menu__item">
# <a class="main-menu__link" href="/cars/?userId=22683244">
# <span class="main-menu__label">Авто от Kolesa.kz</span>
# <span class="main-menu__badge">New</span>
# </a>
# </li>
# <li class="main-menu__item">
# <a class="main-menu__link js__new-auto" href="/cars/new/">
# <span class="main-menu__label">Новые авто</span>
# </a>
# </li>
# <li class="main-menu__item">
# <a class="main-menu__link" href="/zapchasti/">
# <span class="main-menu__label">Запчасти</span>
# </a>
# </li>
# <li class="main-menu__item">
# <a class="main-menu__link" href="/uslugi/">
# <span class="main-menu__label">Ремонт и услуги</span>
# </a>
# </li>
# <li class="main-menu__item">
# <a class="main-menu__link" href="/spectehnika/">
# <span class="main-menu__label">Коммерческие</span>
# </a>
# </li>
# <li class="main-menu__item">
# <a class="main-menu__link" href="https://kolesa.kz/content/">
#             Почитать        </a>
# </li>
# <li class="main-menu__item">
# <a class="main-menu__link" href="https://kolesa.kz/content/kolesa-gid/">
#             Гид
#         </a>
# </li>
# </ul>
# </div>
# <div class="main-header__add-a">
# <div class="a-add">
# <a class="a-add__button kl-ui-button kl-ui-button--white js__add-new" data-source="header" data-test="add-advert-main-header-button" href="/a/new/">
# <span class="fi-add-big"></span>
# <span class="label">Подать объявление</span>
# </a>
# <div class="a-add__hint">
#         1 020 622 уже на сайте
#     </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="ui-container">
# <div class="menu-container">
# <nav class="header-menu-list js-header-menu-list">
# <ul class="action-list">
# <li class="action-item">
# <span class="action-link selected" data-alias="cars" data-id="2" data-url="/a/get-search-form/" title="Легковые">Легковые</span>
# </li>
# <li class="action-item">
# <span class="action-link" data-alias="cars/new" data-id="96" data-url="/a/get-search-form/" title="Новые авто из салона">Новые авто из салона</span>
# </li>
# <li class="action-item">
# <span class="action-link shop" data-alias="avtosalon" data-id="55" data-url="/a/get-search-form/" title="Дилеры">Дилеры</span>
# </li>
# <li class="action-item">
# <span class="action-link" data-alias="mototehnika" data-id="6" data-url="/a/get-search-form/" title="Мототехника">Мототехника</span>
# </li>
# <li class="action-item">
# <span class="action-link" data-alias="vodnyj-transport" data-id="47" data-url="/a/get-search-form/" title="Водный транспорт">Водный транспорт</span>
# </li>
# </ul>
# </nav>
# <section class="search-form-content">
# <div class="search-block a-search-form-container">
# <form action="/cars/" method="get">
# <div class="main">
# <div class="primary">
# <div class="basic-settings">
# <div class="element-group element-group-parameter-auto-car-grbody element-group-x element-type-radio">
# <div class="group-element"><div class="field-container" data-field="auto-car-grbody"><div class="element-radio uncheck-element" id="auto-car-grbody"><div class="radio-button"><input class="visually-hidden" id="auto-car-grbody-1" name="auto-car-grbody" type="radio" value="1"/><label for="auto-car-grbody-1"><span class="link link-dashed" title="Легковые">Легковые</span></label></div><div class="radio-button"><input class="visually-hidden" id="auto-car-grbody-2" name="auto-car-grbody" type="radio" value="2"/><label for="auto-car-grbody-2"><span class="link link-dashed" title="Внедорожники и пикапы">Внедорожники и пикапы</span></label></div><div class="radio-button"><input class="visually-hidden" id="auto-car-grbody-3" name="auto-car-grbody" type="radio" value="3"/><label for="auto-car-grbody-3"><span class="link link-dashed" title="Минивены и микроавтобусы">Минивены и микроавтобусы</span></label></div></div></div></div> </div>
# <div class="element-group element-group-region-list hidden-element element-type-select">
# <div class="group-element"><div class="field-container" data-field="region-list"><div class="selectbox" data-for="region-list"><div class="selectbox-select"><input class="used" data-alias="region-almatinskaya-oblast" data-level="101" data-original-name="region.list" data-other-label="Искать во всём регионе" data-parameter-name="region.list" id="region-list" name="region-list" type="hidden" value="1"/><div class="text selected">Алматинская область</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty" data-label="Все" data-value="">Все</li><li class="51" data-alias="region-abaiskaya-oblast" data-geocode="KZ-ABA" data-kz="1" data-la="42.3174" data-label="Абайская область" data-lo="69.6207" data-t="road" data-val_en="Abai region" data-val_kk="Абай облысы" data-value="51" data-z="12">Абайская область</li><li class="2" data-alias="region-akmolinskaya-oblast" data-geocode="KZ-AKM" data-kz="1" data-la="51.128422" data-label="Акмолинская область" data-lo="71.430564" data-t="road" data-val_en="Akmola region" data-val_kk="Ақмола облысы" data-value="2" data-z="12">Акмолинская область</li><li class="3" data-alias="region-aktubinskaya-oblast" data-geocode="KZ-AKT" data-kz="1" data-la="50.2828" data-label="Актюбинская область" data-lo="57.1908" data-t="road" data-val_en="Aktobe region" data-val_kk="Ақтөбе облысы" data-value="3" data-z="12">Актюбинская область</li><li class="1selected" data-alias="region-almatinskaya-oblast" data-geocode="KZ-ALM" data-kz="1" data-la="43.2859" data-label="Алматинская область" data-lo="76.9129" data-m="yandex" data-t="road" data-val_en="Almaty region" data-val_kk="Алматы облысы" data-value="1" data-z="11">Алматинская область</li><li class="4" data-alias="region-atyrauskaya-oblast" data-geocode="KZ-ATY" data-kz="1" data-la="47.1105054" data-label="Атырауская область" data-lo="51.92592" data-t="road" data-val_en="Atyrau region" data-val_kk="Атырау облысы" data-value="4" data-z="12">Атырауская область</li><li class="5" data-alias="region-vostochnokazakhstanskaya-oblast" data-geocode="KZ-VOS" data-kz="1" data-la="49.9809" data-label="Восточно-Казахстанская область" data-lo="82.6104" data-t="road" data-val_en="East Kazakhstan region" data-val_kk="Шығыс Қазақстан облысы" data-value="5" data-z="12">Восточно-Казахстанская область</li><li class="6" data-alias="region-zhambilskaya-oblast" data-geocode="KZ-ZHA" data-kz="1" data-la="42.8916" data-label="Жамбылская область" data-lo="71.3922" data-t="road" data-val_en="Zhambyl region" data-val_kk="Жамбыл облысы" data-value="6" data-z="12">Жамбылская область</li><li class="52" data-alias="region-zhetysuskaya-oblast" data-geocode="KZ-ZHE" data-kz="1" data-la="42.3174" data-label="Жетысуская область" data-lo="69.6207" data-t="road" data-val_en="Zhetysu region" data-val_kk="Жетісу облысы" data-value="52" data-z="12">Жетысуская область</li><li class="7" data-alias="region-zapadnokazakshstabskaya-oblast" data-geocode="KZ-ZAP" data-kz="1" data-la="51.2302" data-label="Западно-Казахстанская область" data-lo="51.4311" data-t="road" data-val_en="West Kazakhstan region" data-val_kk="Батыс Қазақстан облысы" data-value="7" data-z="11">Западно-Казахстанская область</li><li class="8" data-alias="region-karagandinskaya-oblast" data-geocode="KZ-KAR" data-kz="1" data-la="49.836" data-label="Карагандинская область" data-lo="73.1474" data-t="road" data-val_en="Karaganda region" data-val_kk="Қарағанды облысы" data-value="8" data-z="11">Карагандинская область</li><li class="9" data-alias="region-kostanayskaya-oblast" data-geocode="KZ-KUS" data-kz="1" data-la="53.218767" data-label="Костанайская область" data-lo="63.637065" data-t="road" data-val_en="Kostanay region" data-val_kk="Қостанай облысы" data-value="9" data-z="12">Костанайская область</li><li class="10" data-alias="regio ...
# <div class="element-group element-group-region arrow-icon element-type-region">
# <div class="group-element"><div class="field-container" data-field="region"><div class="js__filter-region" data-level="100" data-name="өтеген батыр" data-popular='[{"key":"\u0410\u043b\u043c\u0430\u0442\u044b","value":"\u0410\u043b\u043c\u0430\u0442\u044b","additional":"\u0410\u043b\u043c\u0430\u0442\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","extra":{"info":"\u0410\u043b\u043c\u0430\u0442\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","code":"","alias":"almaty","lo":"76.945465","la":"43.238273","z":"12","val_kk":"\u0410\u043b\u043c\u0430\u0442\u044b","val_en":"Almaty","info_kk":"\u0410\u043b\u043c\u0430\u0442\u044b \u043e\u0431\u043b\u044b\u0441\u044b","info_en":"Almaty region","popular":51359}},{"key":"\u0410\u0441\u0442\u0430\u043d\u0430","value":"\u0410\u0441\u0442\u0430\u043d\u0430","additional":"\u0410\u043a\u043c\u043e\u043b\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","extra":{"info":"\u0410\u043a\u043c\u043e\u043b\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","code":"","alias":"astana","lo":"71.430564","la":"51.128422","z":"12","val_kk":"\u0410\u0441\u0442\u0430\u043d\u0430","val_en":"Astana","info_kk":"\u0410\u049b\u043c\u043e\u043b\u0430 \u043e\u0431\u043b\u044b\u0441\u044b","info_en":"Akmola region","popular":23377}},{"key":"\u041a\u0430\u0440\u0430\u0433\u0430\u043d\u0434\u0430","value":"\u041a\u0430\u0440\u0430\u0433\u0430\u043d\u0434\u0430","additional":"\u041a\u0430\u0440\u0430\u0433\u0430\u043d\u0434\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","extra":{"info":"\u041a\u0430\u0440\u0430\u0433\u0430\u043d\u0434\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","code":"","alias":"karaganda","lo":"73.085494","la":"49.806417","z":"12","val_kk":"\u049a\u0430\u0440\u0430\u0493\u0430\u043d\u0434\u044b","val_en":"Karaganda","info_kk":"\u049a\u0430\u0440\u0430\u0493\u0430\u043d\u0434\u044b \u043e\u0431\u043b\u044b\u0441\u044b","info_en":"Karaganda region","popular":9905}},{"key":"\u0428\u044b\u043c\u043a\u0435\u043d\u0442","value":"\u0428\u044b\u043c\u043a\u0435\u043d\u0442","additional":"\u0422\u0443\u0440\u043a\u0435\u0441\u0442\u0430\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","extra":{"info":"\u0422\u0443\u0440\u043a\u0435\u0441\u0442\u0430\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","code":"","alias":"shymkent","lo":"69.5897","la":"42.317274","z":"12","val_kk":"\u0428\u044b\u043c\u043a\u0435\u043d\u0442","val_en":"Shymkent","info_kk":"\u0422\u04af\u0440\u043a\u0456\u0441\u0442\u0430\u043d \u043e\u0431\u043b\u044b\u0441\u044b","info_en":"Turkistan region","popular":16389}},{"key":"\u0410\u043a\u0442\u043e\u0431\u0435","value":"\u0410\u043a\u0442\u043e\u0431\u0435","additional":"\u0410\u043a\u0442\u044e\u0431\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","extra":{"info":"\u0410\u043a\u0442\u044e\u0431\u0438\u043d\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","code":"","alias":"aktobe","lo":"57.154591","la":"50.300411","z":"12","val_kk":"\u0410\u049b\u0442\u04e9\u0431\u0435","val_en":"Aktobe ","info_kk":"\u0410\u049b\u0442\u04e9\u0431\u0435 \u043e\u0431\u043b\u044b\u0441\u044b","info_en":"Aktobe region","popular":9618}},{"key":"\u041a\u043e\u0441\u0442\u0430\u043d\u0430\u0439","value":"\u041a\u043e\u0441\u0442\u0430\u043d\u0430\u0439","additional":"\u041a\u043e\u0441\u0442\u0430\u043d\u0430\u0439\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","extra":{"info":"\u041a\u043e\u0441\u0442\u0430\u043d\u0430\u0439\u0441\u043a\u0430\u044f \u043e\u0431\u043b\u0430\u0441\u0442\u044c","code":"","alias":"kostanai","lo":"63.630995","la":"53.214938","z":"12","val_kk":"\u049a\u043e\u0441\u0442\u0430\u043d\u0430\u0439","val_en":"Kostanay","info_kk":"\u049a\u043e\u0441\u0442\u0430\u043d\u0430\u0439 \ ...
# <div class="element-group element-group-parameter-brand js__brand-filter element-type-select">
# <div class="group-element"><div class="field-container" data-field="brand"><label class="" for="brand">
#             brand
#                     </label><div class="js__car-selected-data" data-brand-id="" data-generation-ids="[]" data-is-new-auto="" data-model-alias-id="" data-model-id=""></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-emergency element-group-x element-type-radio">
# <div class="group-element"><div class="field-container" data-field="auto-emergency"><div class="element-radio" id="auto-emergency"><div class="radio-button"><input checked="" class="visually-hidden" id="auto-emergency-" name="auto-emergency" type="radio" value=""/><label for="auto-emergency-"><span class="link link-dashed" title="Все">Все</span></label></div><div class="radio-button"><input class="visually-hidden" data-alias="novye-avtomobili" data-level="1" id="auto-emergency-4" name="auto-emergency" type="radio" value="4"/><label for="auto-emergency-4"><span class="link link-dashed" title="Новая">Новая</span></label></div><div class="radio-button"><input class="visually-hidden" data-alias="avtomobili-s-probegom" data-level="1" id="auto-emergency-1" name="auto-emergency" type="radio" value="1"/><label for="auto-emergency-1"><span class="link link-dashed" title="С пробегом">С пробегом</span></label></div></div></div></div> </div>
# </div>
# <div class="additional-settings">
# <div class="element-group element-group-parameter-_sys-hasphoto element-group-x element-type-checkbox">
# <div class="group-element"><div class="field-container" data-field="_sys-hasphoto"><div class="width-box input-group-checkbox"><input class="" id="_sys-hasphoto-checkbox-0" name="_sys-hasphoto" type="checkbox" value="2"><label class="not-alert" for="_sys-hasphoto-checkbox-0">С фото</label></input></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-custom element-group-x element-type-checkbox">
# <div class="group-element"><div class="field-container" data-field="auto-custom"><div class="width-box input-group-checkbox"><input class="" id="auto-custom-checkbox-0" name="auto-custom" type="checkbox" value="2"><label class="not-alert" for="auto-custom-checkbox-0">Растаможен</label></input></div></div></div> </div>
# <div class="element-group element-group-parameter-need-repair element-group-x element-type-checkbox">
# <div class="group-element"><div class="field-container" data-field="need-repair"><div class="width-box input-group-checkbox"><input class="" id="need-repair-checkbox-0" name="need-repair" type="checkbox" value="1"><label class="not-alert" for="need-repair-checkbox-0">Аварийная/Не на ходу</label></input></div></div></div> </div>
# </div>
# <div class="extra-settings">
# <div class="element-group element-group-parameter-who element-group-x element-type-hidden">
# <div class="group-element"><input id="who" name="who" type="hidden"/></div> </div>
# <div class="element-group element-group-parameter-auto_car_equipment element-group-x element-type-hidden">
# <div class="group-element"><input id="auto_car_equipment" name="auto_car_equipment" type="hidden"/></div> </div>
# </div>
# <div class="hidden-sort">
# <input name="sort_by" type="hidden" value=""/>
# </div>
# <div class="advanced-section">
# <div class="toggler">
# <button class="btn set-optional" type="button">
# <span class="fi-settings"></span>
# <span class="label">Расширенный поиск</span>
# <span class="js-advanced-search-filter-counter counter">0</span>
# <span class="fi-arrow-mini"></span>
# </button>
# </div>
# <div class="full-search js-full-search" style="display: none;">
# <div class="primary-options">
# <div class="element-group element-group-parameter-mark-country element-group-x element-type-select">
# <div class="group-element"><div class="field-container" data-field="mark-country"><label class="" for="mark-country">
#             Страна происхождения марки
#                     </label><div class="selectbox" data-for="mark-country"><div class="selectbox-select"><input class="" data-original-name="mark-country" data-parameter-name="mark-country" id="mark-country" name="mark-country" type="hidden" value=""/><div class="text">Страна происхождения марки</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty selected" data-label="Страна происхождения марки" data-value="">Страна происхождения марки</li><li class="14" data-label="Европа" data-many-0="1" data-many-1="2" data-many-2="3" data-many-3="4" data-many-4="5" data-many-5="6" data-many-6="7" data-val_en="Europe" data-val_kk="Еуропа" data-value="14" data-visible="false">Европа</li><li &nbsp;&nbsp;-="" class="1" data-invisible-prefix="   - " data-label="Англия" data-val_en="England" data-val_kk="Англия" data-value="1">Англия</li><li &nbsp;&nbsp;-="" class="2" data-invisible-prefix="   - " data-label="Германия" data-val_en="Germany" data-val_kk="Германия" data-value="2">Германия</li><li &nbsp;&nbsp;-="" class="3" data-invisible-prefix="   - " data-label="Италия" data-val_en="Italy" data-val_kk="Италия" data-value="3">Италия</li><li &nbsp;&nbsp;-="" class="4" data-invisible-prefix="   - " data-label="Испания" data-val_en="Spain" data-val_kk="Испания" data-value="4">Испания</li><li &nbsp;&nbsp;-="" class="5" data-invisible-prefix="   - " data-label="Франция" data-val_en="France" data-val_kk="Франция" data-value="5">Франция</li><li &nbsp;&nbsp;-="" class="6" data-invisible-prefix="   - " data-label="Чехия" data-val_en="Czech Republic" data-val_kk="Чехия" data-value="6">Чехия</li><li &nbsp;&nbsp;-="" class="7" data-invisible-prefix="   - " data-label="Швеция" data-val_en="Sweden" data-val_kk="Швеция" data-value="7">Швеция</li><li class="8" data-label="Китай" data-val_en="China" data-val_kk="Қытай" data-value="8">Китай</li><li class="9" data-label="Южная Корея" data-val_en="South Korea" data-val_kk="Оңтүстік Корея" data-value="9">Южная Корея</li><li class="10" data-label="Россия" data-val_en="Russia" data-val_kk="Ресей" data-value="10">Россия</li><li class="11" data-label="США" data-val_en="USA" data-val_kk="АҚШ" data-value="11">США</li><li class="12" data-label="Япония" data-val_en="Japan" data-val_kk="Жапония" data-value="12">Япония</li><li class="13last" data-label="Другие страны" data-val_en="Other countries" data-val_kk="Басқа елдер" data-value="13">Другие страны</li></ul></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-car-body element-group-x element-type-select">
# <div class="group-element"><div class="field-container" data-field="auto-car-body"><label class="" for="auto-car-body">
#             Кузов
#                     </label><div class="selectbox" data-for="auto-car-body"><div class="selectbox-select"><input class="" data-level="1" data-original-name="auto.car.body" data-parameter-name="auto.car.body" id="auto-car-body" name="auto-car-body" type="hidden" value=""/><div class="text">Кузов</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty selected" data-label="Кузов" data-value="">Кузов</li><li class="11" data-alias="sedan" data-data-grbody="1" data-label="седан" data-val_en="sedan" data-val_kk="седан" data-value="11">седан</li><li class="12" data-alias="station-wagon" data-data-grbody="1" data-label="универсал" data-val_en="estate" data-val_kk="универсал" data-value="12">универсал</li><li class="13" data-alias="hatchback" data-data-grbody="1" data-label="хэтчбек" data-val_en="hatchback" data-val_kk="хэтчбек" data-value="13">хэтчбек</li><li class="16" data-alias="limousine" data-data-grbody="1" data-label="лимузин" data-val_en="limousine" data-val_kk="лимузин" data-value="16">лимузин</li><li class="14" data-alias="body-coupe" data-data-grbody="1" data-label="купе" data-val_en="coupe" data-val_kk="купе" data-value="14">купе</li><li class="19" data-alias="body-roadster" data-data-grbody="1" data-label="родстер" data-val_en="roadster" data-val_kk="родстер" data-value="19">родстер</li><li class="15" data-alias="cabriolet" data-data-grbody="1" data-label="кабриолет" data-val_en="convertible" data-val_kk="кабриолет" data-value="15">кабриолет</li><li class="21" data-alias="suv" data-data-grbody="2" data-label="внедорожник" data-val_en="SUV" data-val_kk="жол талғамайтын көлік" data-value="21">внедорожник</li><li class="23" data-alias="crossover-suv" data-data-grbody="2" data-label="кроссовер" data-val_en="crossover" data-val_kk="кроссовер" data-value="23">кроссовер</li><li class="17" data-alias="microvan" data-data-grbody="3" data-label="микровэн" data-val_en="microvan" data-val_kk="микровэн" data-value="17">микровэн</li><li class="31" data-alias="minivan" data-data-grbody="3" data-label="минивэн" data-val_en="minivan" data-val_kk="минивэн" data-value="31">минивэн</li><li class="32" data-alias="van" data-data-grbody="3" data-label="микроавтобус" data-val_en="minibus" data-val_kk="микроавтобус" data-value="32">микроавтобус</li><li class="18" data-alias="wagon" data-data-grbody="3" data-label="фургон" data-val_en="cargo van" data-val_kk="фургон" data-value="18">фургон</li><li class="22" data-alias="body-pickup" data-data-grbody="2" data-label="пикап" data-val_en="pickup" data-val_kk="пикап" data-value="22">пикап</li><li class="33" data-alias="targa" data-data-grbody="1" data-label="тарга" data-val_en="targa" data-val_kk="тарга" data-value="33">тарга</li><li class="34" data-alias="fastback" data-data-grbody="1" data-label="фастбек" data-val_en="fastback" data-val_kk="фастбек" data-value="34">фастбек</li><li class="35" data-alias="liftback" data-data-grbody="1" data-label="лифтбек" data-val_en="liftback" data-val_kk="лифтбек" data-value="35">лифтбек</li><li class="36last" data-alias="hardtop" data-data-grbody="1" data-label="хардтоп" data-val_en="hardtop" data-val_kk="хардтоп" data-value="36">хардтоп</li></ul></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-fuel element-group-x element-type-select">
# <div class="group-element"><div class="field-container" data-field="auto-fuel"><label class="" for="auto-fuel">
#             Тип топлива
#                     </label><div class="selectbox" data-for="auto-fuel"><div class="selectbox-select"><input class="" data-original-name="auto.fuel" data-parameter-name="auto.fuel" id="auto-fuel" name="auto-fuel" type="hidden" value=""/><div class="text">Тип двигателя</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty selected" data-label="Тип двигателя" data-value="">Тип двигателя</li><li class="1" data-label="бензин" data-val_en="petrol" data-val_kk="бензин" data-value="1">бензин</li><li class="2" data-label="дизель" data-val_en="diesel" data-val_kk="дизель" data-value="2">дизель</li><li class="3" data-label="газ-бензин" data-val_en="gas-petrol" data-val_kk="газ-бензин" data-value="3">газ-бензин</li><li class="4" data-label="газ" data-val_en="gas  " data-val_kk="газ" data-value="4">газ</li><li class="5" data-label="гибрид" data-val_en="hybrid" data-val_kk="гибрид" data-value="5">гибрид</li><li class="6last" data-label="электричество" data-val_en="electricity" data-val_kk="электр қуаты" data-value="6">электричество</li></ul></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-car-transm element-group-x element-type-select">
# <div class="group-element"><div class="field-container" data-field="auto-car-transm"><label class="" for="auto-car-transm">
#             Коробка передач
#                     </label><div class="selectbox" data-for="auto-car-transm"><div class="selectbox-select"><input class="" data-original-name="auto.car.transm" data-parameter-name="auto.car.transm" id="auto-car-transm" name="auto-car-transm" type="hidden" value=""/><div class="text">КПП</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty selected" data-label="КПП" data-value="">КПП</li><li class="1" data-label="механика" data-val_en="manual transmission" data-val_kk="механика" data-value="1">механика</li><li class="2345" data-label="АКПП" data-many-0="2" data-many-1="3" data-many-2="4" data-many-3="5" data-val_en="automatic transmission" data-val_kk="АБАҚ" data-value="2345" data-visible="false">АКПП</li><li &nbsp;&nbsp;-="" class="2" data-invisible-prefix="   - " data-label="автомат" data-val_en="automatic  " data-val_kk="автомат" data-value="2">автомат</li><li &nbsp;&nbsp;-="" class="3" data-invisible-prefix="   - " data-label="типтроник" data-val_en="tiptronic" data-val_kk="типтроник" data-value="3">типтроник</li><li &nbsp;&nbsp;-="" class="4" data-invisible-prefix="   - " data-label="вариатор" data-val_en="variable speed transmission" data-val_kk="вариатор" data-value="4">вариатор</li><li &nbsp;&nbsp;-="" class="5last" data-invisible-prefix="   - " data-label="робот" data-val_en="robotised gearbox" data-val_kk="робот" data-value="5">робот</li></ul></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-sweel element-group-x element-type-select">
# <div class="group-element"><div class="field-container" data-field="auto-sweel"><label class="" for="auto-sweel">
#             Руль
#                     </label><div class="selectbox" data-for="auto-sweel"><div class="selectbox-select"><input class="" data-original-name="auto.sweel" data-parameter-name="auto.sweel" id="auto-sweel" name="auto-sweel" type="hidden" value=""/><div class="text">Расположение руля</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty selected" data-label="Расположение руля" data-value="">Расположение руля</li><li class="1" data-label="слева" data-val_en="left" data-val_kk="сол жақта" data-value="1">слева</li><li class="2last" data-label="справа" data-val_en="right" data-val_kk="оң жақта" data-value="2">справа</li></ul></div></div></div> </div>
# <div class="element-group element-group-parameter-car-dwheel element-group-x element-type-select">
# <div class="group-element"><div class="field-container" data-field="car-dwheel"><label class="" for="car-dwheel">
#             Привод
#                     </label><div class="selectbox" data-for="car-dwheel"><div class="selectbox-select"><input class="" data-original-name="car.dwheel" data-parameter-name="car.dwheel" id="car-dwheel" name="car-dwheel" type="hidden" value=""/><div class="text">Привод</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty selected" data-label="Привод" data-value="">Привод</li><li class="1" data-label="передний привод" data-val_en="FWD" data-val_kk="алдыңғы жетек" data-value="1">передний привод</li><li class="2" data-label="полный привод" data-val_en="AWD" data-val_kk="толық жетек" data-value="2">полный привод</li><li class="3last" data-label="задний привод" data-val_en="RWD" data-val_kk="артқы жетек" data-value="3">задний привод</li></ul></div></div></div> </div>
# </div>
# <div class="secondary-options">
# <div class="element-group element-group-auto-run element-group-with-label element-group-x-x element-group-xs element-type-numeric">
# <label class="group-label" for="auto-run[to]">Пробег не более, км</label><div class="group-element"><div class="field-container" data-field="auto-run[to]"><div class="element-text"><input id="auto-run[to]" min="0" name="auto-run[to]" type="number"/></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-car-order element-group-x element-type-radio">
# <div class="group-element"><div class="field-container" data-field="auto-car-order"><label class="" for="auto-car-order">
#             Наличие
#                     </label><div class="element-radio uncheck-element" id="auto-car-order"><div class="radio-button"><input class="visually-hidden" id="auto-car-order-1" name="auto-car-order" type="radio" value="1"/><label for="auto-car-order-1"><span class="link link-dashed" title="В наличии">В наличии</span></label></div><div class="radio-button"><input class="visually-hidden" id="auto-car-order-2" name="auto-car-order" type="radio" value="2"/><label for="auto-car-order-2"><span class="link link-dashed" title="На заказ">На заказ</span></label></div></div></div></div> </div>
# <div class="element-group element-group-auto-car-volume element-group-with-label element-group-x-x element-type-numeric">
# <label class="group-label" for="auto-car-volume[from]">Объем двигателя, л</label><div class="group-element"><div class="field-container" data-field="auto-car-volume[from]"><div class="element-text"><input id="auto-car-volume[from]" max="10.0" min="0.1" name="auto-car-volume[from]" placeholder=" от" step="0.01" type="number"/></div></div><div class="field-container" data-field="auto-car-volume[to]"><label class="" for="auto-car-volume[to]">
#             —
#                     </label><div class="element-text"><input id="auto-car-volume[to]" max="10.0" min="0.1" name="auto-car-volume[to]" placeholder=" до" step="0.01" type="number"/></div></div></div> </div>
# <div class="element-group element-group-parameter-auto-color element-group-s element-type-select element-type-checkbox">
# <div class="group-element"><div class="field-container" data-field="auto-color"><label class="" for="auto-color">
#             Цвет
#                     </label><div class="selectbox" data-for="auto-color"><div class="selectbox-select"><input class="" data-original-name="auto.color" data-parameter-name="auto.color" id="auto-color" name="auto-color" type="hidden" value=""/><div class="text">Не важно</div><div class="arrow"><span class="fi-arrow-bottom"></span></div></div><ul class="selectbox-options"><li class="system search hidden"><input autocomplete="off" placeholder="Поиск…" type="text"><div class="not-found">Совпадений не найдено</div></input></li><li class="empty selected" data-label="Не важно" data-value="">Не важно</li><li class="9" data-label="бронза" data-val_en="bronze" data-val_kk="қола түсті" data-value="9">бронза</li><li class="21" data-label="вишня" data-val_en="cherry" data-val_kk="шие" data-value="21">вишня</li><li class="18" data-label="хамелеон" data-val_en="chameleon" data-val_kk="хамелеон" data-value="18">хамелеон</li><li class="11" data-label="бежевый" data-val_en="beige" data-val_kk="сарғыш" data-value="11">бежевый</li><li class="1" data-label="белый" data-val_en="white" data-val_kk="ақ" data-value="1">белый</li><li class="23" data-label="бирюзовый" data-val_en="turquoise" data-val_kk="көгілдір" data-value="23">бирюзовый</li><li class="22" data-label="бордовый" data-val_en="vinous" data-val_kk="күрең" data-value="22">бордовый</li><li class="12" data-label="голубой" data-val_en="light blue" data-val_kk="көк" data-value="12">голубой</li><li class="15" data-label="жёлтый" data-val_en="yellow" data-val_kk="сары" data-value="15">жёлтый</li><li class="3" data-label="зеленый" data-val_en="green" data-val_kk="жасыл" data-value="3">зеленый</li><li class="8" data-label="золотистый" data-val_en="golden" data-val_kk="алтын" data-value="8">золотистый</li><li class="13" data-label="коричневый" data-val_en="brown" data-val_kk="қоңыр" data-value="13">коричневый</li><li class="4" data-label="красный" data-val_en="red" data-val_kk="қызыл" data-value="4">красный</li><li class="16" data-label="оранжевый" data-val_en="orange" data-val_kk="сарғылт" data-value="16">оранжевый</li><li class="20" data-label="розовый" data-val_en="pink" data-val_kk="қызғылт" data-value="20">розовый</li><li class="2" data-label="серебристый" data-val_en="silver" data-val_kk="күміс" data-value="2">серебристый</li><li class="5" data-label="серый" data-val_en="grey" data-val_kk="сұр" data-value="5">серый</li><li class="7" data-label="синий" data-val_en="blue" data-val_kk="көк" data-value="7">синий</li><li class="17" data-label="сиреневый" data-val_en="lilac" data-val_kk="ақшыл көк" data-value="17">сиреневый</li><li class="14" data-label="фиолетовый" data-val_en="violet" data-val_kk="күлгін" data-value="14">фиолетовый</li><li class="6last" data-label="черный" data-val_en="black" data-val_kk="қара" data-value="6">черный</li></ul></div></div><div class="field-container" data-field="auto-color_m"><div class="width-box input-group-checkbox"><input class="" data-val_en="metallic" data-val_kk="металлик" id="auto-color_m-checkbox-0" name="auto-color_m" type="checkbox" value="1"><label class="not-alert" for="auto-color_m-checkbox-0">металлик</label></input></div></div></div> </div>
# <div class="element-group element-group-parameter-is-dealer element-group--align element-type-checkbox">
# <div class="group-element"><div class="field-container" data-field="is-dealer"><div class="width-box input-group-checkbox"><input class="" data-many-0="4" data-many-1="7" id="is-dealer-checkbox-0" name="is-dealer" type="checkbox" value="1"/><label class="not-alert" for="is-dealer-checkbox-0">От дилеров</label></div></div></div> </div>
# <div class="element-group element-group-parameter-text text-big-size element-type-text element-group-hint">
# <div class="group-element"><div class="field-container" data-field="_txt_"><label class="" for="_txt_">
#             Что ищем?
#                     </label><div class="element-text"><input id="_txt_" name="_txt_" placeholder="Что ищем?" type="text"/></div></div></div><div class="group-hint">Поиск по ключевым словам</div> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="secondary">
# <div class="element-group element-group-year element-group-with-label element-group-x-x element-type-numeric">
# <label class="group-label" for="year[from]">Год выпуска</label><div class="group-element"><div class="field-container" data-field="year[from]"><div class="element-text"><input id="year[from]" max="2023" min="1900" name="year[from]" placeholder="от" type="number"/></div></div><div class="field-container" data-field="year[to]"><label class="" for="year[to]">
#             —
#                     </label><div class="element-text"><input id="year[to]" max="2023" min="1900" name="year[to]" placeholder="до" type="number"/></div></div></div> </div>
# <div class="element-group element-group-price element-group-with-label element-group-x-x element-type-text">
# <label class="group-label" for="price[from]">Цена</label><div class="group-element"><div class="field-container" data-field="price[from]"><div class="element-text"><input class="mask-money-price" id="price[from]" name="price[from]" placeholder="от" type="text"/></div></div><div class="field-container" data-field="price[to]"><label class="" for="price[to]">
#             —
#                     </label><div class="element-text"><input class="mask-money-price" id="price[to]" name="price[to]" placeholder="до" type="text"/><span class="after-text"> тг</span></div></div></div> </div>
# <div class="element-group element-group-parameter-acr-credit element-group-x element-type-checkbox">
# ...
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="62">
# <a href="/cars/new/baic/region-almatinskaya-oblast/">BAIC</a>
# <span class="cross-links__count">5</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="63">
# <a href="/cars/new/denza/region-almatinskaya-oblast/">Denza</a>
# <span class="cross-links__count">4</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="64">
# <a href="/cars/new/aito/region-almatinskaya-oblast/">Aito</a>
# <span class="cross-links__count">4</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="65">
# <a href="/cars/new/bentley/region-almatinskaya-oblast/">Bentley</a>
# <span class="cross-links__count">3</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="66">
# <a href="/cars/new/mini/region-almatinskaya-oblast/">Mini</a>
# <span class="cross-links__count">3</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="67">
# <a href="/cars/new/mg/region-almatinskaya-oblast/">MG</a>
# <span class="cross-links__count">3</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="68">
# <a href="/cars/new/polar-stone/region-almatinskaya-oblast/">Polar Stone</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="69">
# <a href="/cars/new/dfsk/region-almatinskaya-oblast/">DFSK</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="70">
# <a href="/cars/new/trumpchi/region-almatinskaya-oblast/">GAC Trumpchi</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="71">
# <a href="/cars/new/radar/region-almatinskaya-oblast/">Radar</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="72">
# <a href="/cars/new/xpeng/region-almatinskaya-oblast/">Xpeng</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="73">
# <a href="/cars/new/seres/region-almatinskaya-oblast/">Seres</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="74">
# <a href="/cars/new/nio/region-almatinskaya-oblast/">Nio</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="75">
# <a href="/cars/new/weltmeister/region-almatinskaya-oblast/">Weltmeister</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="76">
# <a href="/cars/new/baw/region-almatinskaya-oblast/">BAW</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="77">
# <a href="/cars/new/polestar/region-almatinskaya-oblast/">Polestar</a>
# <span class="cross-links__count">2</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="78">
# <a href="/cars/new/kaiyi/region-almatinskaya-oblast/">Kaiyi</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="79">
# <a href="/cars/new/yema/region-almatinskaya-oblast/">Yema</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="80">
# <a href="/cars/new/baojun/region-almatinskaya-oblast/">Baojun</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="81">
# <a href="/cars/new/rivian/region-almatinskaya-oblast/">Rivian</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="82">
# <a href="/cars/new/jetta/region-almatinskaya-oblast/">Jetta</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="83">
# <a href="/cars/new/zotye/region-almatinskaya-oblast/">Zotye</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="84">
# <a href="/cars/new/enovate/region-almatinskaya-oblast/">Enovate</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="85">
# <a href="/cars/new/dayun/region-almatinskaya-oblast/">Dayun</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="86">
# <a href="/cars/new/soueast/region-almatinskaya-oblast/">Soueast</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="87">
# <a href="/cars/new/smart/region-almatinskaya-oblast/">Smart</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="88">
# <a href="/cars/new/opel/region-almatinskaya-oblast/">Opel</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="89">
# <a href="/cars/new/mazda/region-almatinskaya-oblast/">Mazda</a>
# <span class="cross-links__count">1</span>
# </li>
# <li class="cross-links__item cross-links__item--hidden js__links-item" data-rank="90">
# <a href="/cars/new/nl/region-almatinskaya-oblast/">NL</a>
# <span class="cross-links__count">1</span>
# </li>
# </ul>
# </div>
# <div class="cheat-notice">
# <h2>
#                         Осторожно, мошенники!                    </h2>
# <p class="small">
#                                                 Вы нашли объявление о продаже машины в отличном состоянии по низкой цене? Вам предлагают отправить деньги переводом? Будьте осторожны. <br/>Возможно, это — <a href="https://kolesa.kz/content/kak-ne-stat-zhertvoj-moshennikov-pri-pokupke-i-prodazhe-avto/" target="_blank">мошенничество</a>.
#                     </p>
# </div>
# </div>
# </div>
# </div>
# <div class="row list-item">
# <div class="col-sm-12 col-md-12 col-lg-12">
# <div class="b-container"><div class="common-b place-Kolesa_Cars_Leaderboard2_970x250" id="place-Kolesa_Cars_Leaderboard2_970x250"><div class="js__adfox-banner" data-params='{"pp":"g","ps":"crwk","p2":"gpyz"}' id="adfox_157433893677756122"></div>
# </div></div>
# </div>
# </div>
# </div>
# </main>
# </div>
# <footer class="ui-footer">
# <div class="ui-container">
# <div class="ui-footer__header">
# <img alt="kolesa.kz" class="ui-footer__logo" src="//kolesa.kz/static/frontend/images/kolesa-logo-new.svg" width="100"/>
# </div>
# <div class="ui-footer__content">
# <ul class="ui-footer__menu">
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="https://kolesa.group/" target="_blank">
#                             О компании «Kolesa Group»
#                         </a>
# </li>
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="/messages/?openSupportThread=1">
#                             Написать в Службу заботы
#                         </a>
# </li>
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="https://job.kolesa.kz/" target="_blank">
#                             Работа в «Kolesa Group»
#                         </a>
# </li>
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="/sitemap/">
#                             Карта сайта
#                         </a>
# </li>
# </ul>
# <ul class="ui-footer__menu">
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="https://special.kolesa.group/reklamodatelyam" rel="nofollow" target="_blank">
#                             Рекламодателям
#                         </a>
# </li>
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="https://kolesa.kz/content/service-regulations/" rel="nofollow" target="_blank">
#                             Правила размещения объявлений
#                         </a>
# </li>
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="https://kolesa.kz/content/agreement/">
#                             Пользовательское соглашение
#                         </a>
# </li>
# </ul>
# <ul class="ui-footer__menu">
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="https://redirect.appmetrica.yandex.com/serve/818270543760339127" rel="nofollow" target="_blank">
#                             Скачать приложение
#                         </a>
# </li>
# <li class="ui-footer__menu-item">
# <a class="ui-footer__link" href="//m.kolesa.kz/cars/region-almatinskaya-oblast/?page=2">
#                                 Мобильная версия сайта
#                             </a>
# </li>
# </ul>
# <div>
#                     Следите за нашими новостями
#                     <div class="ui-footer__social-links">
# <ul class="social-links">
# <li class="social-links__item">
# <a class="social-links__link" href="https://www.instagram.com/kolesa.kz" rel="nofollow" target="_blank" title="kolesa.kz в Instagram">
# <img alt="kolesa.kz в Instagram" class="social-links__icon" height="24" src="//kolesa.kz/static/frontend/images/social/instagram.svg" width="24"/>
# </a>
# </li>
# <li class="social-links__item">
# <a class="social-links__link" href="https://www.youtube.com/@kolesakzvideo" rel="nofollow" target="_blank" title="kolesa.kz в YouTube">
# <img alt="kolesa.kz в YouTube" class="social-links__icon" height="24" src="//kolesa.kz/static/frontend/images/social/youtube.svg" width="24"/>
# </a>
# </li>
# <li class="social-links__item">
# <a class="social-links__link" href="https://t.me/kolesakz_official" rel="nofollow" target="_blank" title="kolesa.kz в Telegram">
# <img alt="kolesa.kz в Telegram" class="social-links__icon" height="24" src="//kolesa.kz/static/frontend/images/social/telegram.svg" width="24"/>
# </a>
# </li>
# <li class="social-links__item">
# <a class="social-links__link" href="https://www.tiktok.com/@kolesakz" rel="nofollow" target="_blank" title="kolesa.kz в TikTok">
# <img alt="kolesa.kz в TikTok" class="social-links__icon" height="24" src="//kolesa.kz/static/frontend/images/social/tiktok.svg" width="24"/>
# </a>
# </li>
# <li class="social-links__item">
# <a class="social-links__link" href="https://vk.com/kolesakz" rel="nofollow" target="_blank" title="kolesa.kz в VK">
# <img alt="kolesa.kz в VK" class="social-links__icon" height="24" src="//kolesa.kz/static/frontend/images/social/vk.svg" width="24"/>
# </a>
# </li>
# <li class="social-links__item">
# <a class="social-links__link" href="https://www.facebook.com/Kolesakz" rel="nofollow" target="_blank" title="kolesa.kz в Facebook">
# <img alt="kolesa.kz в Facebook" class="social-links__icon" height="24" src="//kolesa.kz/static/frontend/images/social/facebook.svg" width="24"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="ui-footer__footer">
#             © 2006 — 2023 АО Колеса
#             <img src="/images/pixel.png">
# </img></div>
# </div>
# </footer>
# </div>
# <script>
#             window.digitalData = {"version":"1.1.2","page":{"type":"listing","category":"Category Listing","isVipBlock":true,"isNewAuto":false},"website":{"environment":"production","type":"desktop"},"user":{"isLoggedIn":false},"listing":{"filters":{"region":"KZ-ALM"},"section":"auto","categoryString":"auto.car","category":["auto","auto.car"],"categoryId":2},"context":{"ip":"46.34.131.101"}};
#
#     if (typeof listing != 'undefined'
#         && listing.items.length > 0
#         && typeof window.digitalData.listing != 'undefined') {
#         Object.assign(window.digitalData.listing, listing);
#     }
#     </script>
# <script id="guideHintTemplate" type="text/x-template">
#         <div class="hints">
#     <div class="hints__container">
#         <div class="hints__main">
#             <div class="hints__main-title">
#                 {{ title }}            </div>
#             <div class="hints__main-text">
#                 {{ text }}            </div>
#             <button class="hints__main-close-button close-guide-hint" type="button">
#                 Скрыть подсказку            </button>
#             <span class="hints__main-caret"></span>
#         </div>
#     </div>
# </div>    </script>
# <script type="text/javascript">
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-20095517-1', 'kolesa.kz');
#
#     ga('require', 'GTM-KT7SL72');
#
#     ga('send', 'pageview');
# </script>
# <script type="text/javascript">
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter10095472 = new Ya.Metrika({id:10095472,
#                     clickmap:true,
#                     accurateTrackBounce:true,
#                     webvisor: false,
#                     ut:"noindex",params:window.yaParams||{ }});
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#                 s = d.createElement("script"),
#                 f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/10095472?ut=noindex" style="position:absolute; left:-9999px;"/></div></noscript>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-M6NQ9S" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script type="text/javascript">
#     var yaParams = {
#         region : "Все регионы",
#         cat    : "cars"
#     };
# </script>
# <script src="//kolesa.kz/static/frontend/js/ru.0464fbef6b.js"></script>
# <script src="//kolesa.kz/static/frontend/js/main-old-browser.1bfa62318e.js"></script>
# <script src="//kolesa.kz/static/frontend/js/main-vendor.8998880618.js"></script>
# <script src="//kolesa.kz/static/frontend/js/main-common.87a9c6188e.js"></script>
# <script src="//kolesa.kz/static/frontend/js/main-payment.db3e86a1a1.js"></script>
# <script src="//kolesa.kz/static/frontend/js/main-hints.c6504572d4.js"></script>
# <script src="https://id.kolesa.kz/authToken.js"></script>
# <script src="//kolesa.kz/static/frontend/js/main-a.f21f228076.js"></script>
# <script id="fav-register" type="text/x-template">
#     <div class="merge row">
#         <div class="col-sm-2">
#             <div class="merge-modal-icon">
#                 <span class="fi-tab-star-filled"></span>
#             </div>
#         </div>
#         <div class="col-sm-10">
#             <div class="modal-header">
#                 Необходимо авторизоваться            </div>
#             <div class="modal-body">
#                 <div>
#                                                             Чтобы сохранить больше 10 избранных объявлений нужно <a href="/signin?backUrl=https%3A%2F%2Fkolesa.kz%2Fcars%2Fregion-almatinskaya-oblast%2F%3Fpage%3D2">войти</a> или <a href="/passport/register/">зарегистрироваться</a>                </div>
#             </div>
#             <div class="modal-footer">
#                 <a href="/signin?backUrl=https%3A%2F%2Fkolesa.kz%2Fcars%2Fregion-almatinskaya-oblast%2F%3Fpage%3D2" class="btn button">
#                     Войти                </a>
#                 <a href="/passport/register/">
#                     Не зарегистрирован?                </a>
#             </div>
#         </div>
#     </div>
# </script>
# <section class="js__nps"></section>
# <script async="" src="/cdn.js" type="text/javascript"></script>
# </body>
# </html>

# %%
car_links = []

for i in range(1, 500): #We set needed amount of pages which we would like to scrape
    ua = UserAgent()
    headers = {'User-Agent': f'{ua.random}'}
    if i == 1:
        request = urllib.request.Request(url3, headers=headers)
        source = urllib.request.urlopen(request, timeout=8.5).read()
        soup = BeautifulSoup(source, features="html.parser")
        cards = soup.find_all("div", class_="a-list__item")
    
        for card in cards:
            car_link = card.find('a', class_='a-card__link')
            if car_link is not None:
                car_links.append(url1 + car_link.get('href'))
    else:
        request = urllib.request.Request(url2.format(i), headers=headers)
        source = urllib.request.urlopen(request, timeout=8.5).read()
        soup = BeautifulSoup(source, features="html.parser")
        cards = soup.find_all("div", class_="a-list__item")
    
        for card in cards:
            car_link = card.find('a', class_='a-card__link')
            if car_link is not None:
                car_links.append(url1 + car_link.get('href'))
    time.sleep(8.5)

# %% [markdown]
# ***Deleting duplicates from obtained list of car links***

# %%
mylist = list(dict.fromkeys(car_links))
print(len(mylist))
# Out:
# 4819

# %% [markdown]
# ***Saving the each obtained list as a file for future summing all of them***

# %%
with open("car_links_1_500_alm", "wb") as fp:   #Pickling
    pickle.dump(car_links_1_500_upd, fp)

# %% [markdown]
# # Creating the list of 30K+ links of cars

# %% [markdown]
# ***Here we call obtained lists***

# %%
with open("car_links_1_500_alm", "rb") as fp:
    list_alm_500 = pickle.load(fp)

with open("car_links_500_1000_alm_dimash", "rb") as fp2:
    list_alm_1000 = pickle.load(fp2)

with open("car_links_1_500_akm_Arlan", "rb") as fp3:
    list_akm_500 = pickle.load(fp3)

with open("car_links_1_150_man", "rb") as fp4:
    list_man_150 = pickle.load(fp4)

# %% [markdown]
# ***Combine them into one***

# %%
list_30k_car_links = list(dict.fromkeys(list_alm_500 + list_alm_1000 + list_akm_500 + list_man_150))
len(list_30k_car_links)
# Out:
# 30884

# %% [markdown]
# ***Save***

# %%
with open("list_30k_car_links", "wb") as fp:
    pickle.dump(list_30k_car_links, fp)

# %% [markdown]
# ***Call***

# %%
with open("list_30k_car_links", "rb") as fp:
    list_30k_car_links = pickle.load(fp)
print(type(list_30k_car_links))
print(len(list_30k_car_links))
# Out:
# <class 'list'>
# 30884

# %% [markdown]
# ***Because of problems with scraping and some car advertisements were deleted we started again gathering car links, now from East Kaz state***

# %%
with open("car_links_1_250_vos", "wb") as fp:
    pickle.dump(mylist, fp)

# %%
with open("car_links_1_250_vos", "rb") as fp:
    car_links_1_250_vos = pickle.load(fp)
print(len(car_links_1_250_vos))
# Out:
# 4819

# %% [markdown]
# # Getting the main info about each car from carlink, which we will add to the final csv file

# %% [markdown]
# ***Dividing the dataset into 3 parts***

# %%
#Arlan
Arlan_links = list_30k_car_links[10884:20884]
with open("Arlan_links", "wb") as fp:
    pickle.dump(Arlan_links, fp)

# %%
#Dimash
Dimash_links = list_30k_car_links[20884:]
with open("Dimash_links", "wb") as fp:
    pickle.dump(Dimash_links, fp)

# %%
Imash_links = list_30k_car_links[:10884]
len(Imash_links)
# Out:
# 10884

# %% [markdown]
# ***Creating empty lists of features which we would like to scrape from each link, this lists will be used to construct dataframe***

# %%
Brand = []
Name = []
Price = []
Year = []
City = []
Car_case = []
Volume = []
Transmission = []
Mileage = []
Gear = []
Steer_wheel = []
Color = []
Custom_clearance = []

# %% [markdown]
# ***Scraping from each link***

# %%
for car in car_links_1_250_vos[2200:3000]:
    ua = UserAgent()
    headers = {'User-Agent': f'{ua.random}'}
    request_car = urllib.request.Request(car, headers=headers)
    try:
        source_car = urllib.request.urlopen(request_car, timeout=8.5).read()
        soup_for_cars = BeautifulSoup(source_car, features="html.parser")
        soup_for_cars_bny = soup_for_cars.find('h1', class_='offer__title')
        Brand.append(soup_for_cars_bny.find('span', itemprop="brand").text.strip())
        try:
            Name.append(soup_for_cars_bny.find('span', itemprop="name").text.strip())
        except:
            Name.append(None)
            
        Year.append(soup_for_cars_bny.find('span', class_="year").text.strip())
        Price.append(soup_for_cars.find('div', class_='offer__price').text.strip().replace('\n', '').replace('\xa0', '').replace('₸', '').strip())
        City.append(soup_for_cars.select_one('dt.value-title[title="Город"] + dd.value').text.strip())
        
        try:
            Car_case.append(soup_for_cars.select_one('dt.value-title[title="Кузов"] + dd.value').text.strip())
        except:
            Car_case.append(None)
        
        try:
            Volume.append(soup_for_cars.select_one('dt.value-title[title="Объем двигателя, л"] + dd.value').text.strip().split(' ')[0])
        except:
            Volume.append(None)
        
        try:
            Transmission.append(soup_for_cars.select_one('dt.value-title[title="Коробка передач"] + dd.value').text.strip())
        except:
            Transmission.append(None)
            
        try:
            Mileage.append(soup_for_cars.select_one('dt.value-title[title="Пробег"] + dd.value').text.strip().replace(' ', '').replace('км', '').strip())
        except:
            Mileage.append(None)
            
        
        try:
            Gear.append(soup_for_cars.select_one('dt.value-title[title="Привод"] + dd.value').text.strip())
        except:
            Gear.append(None)
        
        try:
            Steer_wheel.append(soup_for_cars.select_one('dt.value-title[title="Руль"] + dd.value').text.strip()) 
        except:
            Steer_wheel.append(None)
        
        try:
            Color.append(soup_for_cars.select_one('dt.value-title[title="Цвет"] + dd.value').text.strip())
        except:
            Color.append(None)
        
        try:
            Custom_clearance.append(soup_for_cars.select_one('dt.value-title[title="Растаможен в Казахстане"] + dd.value').text.strip())
        except:
            Custom_clearance.append(None)
    except:
        pass
    time.sleep(8.5)

# %% [markdown]
# ***Checking the length of each list to observe the possible missings***

# %%
print(len(Brand))
print(len(Name))
print(len(Price))
print(len(Year))
print(len(City))
print(len(Car_case))
print(len(Volume))
print(len(Mileage))
print(len(Transmission))
print(len(Gear))
print(len(Steer_wheel))
print(len(Color))
print(len(Custom_clearance))
# Out:
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296
# 1296

# %% [markdown]
# ***Constructing dataframe and saving it***

# %%
df_car = pd.DataFrame(list(zip(Brand, Name, Price, Year, City, Car_case, Volume, Transmission, Mileage, Gear, Steer_wheel, Color, Custom_clearance)), columns =['Brand', 'Name', 'Price', 'Year', 'City', 'Car case', 'Volume', 'Transmission', 'Mileage', 'Gear', 'Steer wheel', 'Color', 'Custom clearance'])
df_car.to_csv('Car_new_2200_3500.csv', index=False)

# %% [markdown]
# # Creating the final dataset with 30k car information

# %% [markdown]
# ***Calling all obtained csv files and summing them***

# %%
df_1_500 = pd.read_csv('Car_1_500.csv')
df_1_500Arlan = pd.read_csv('Car_1_500Arlan.csv')
df_500_1000 = pd.read_csv('Car_500_1000.csv')
df_500_1260Arlan = pd.read_csv('Car_500_1260Arlan.csv')
df_1000_1250 = pd.read_csv('Car_1000_1250.csv')
df_1250_2000 = pd.read_csv('Car_1250_2000.csv')
df_2000_2250 = pd.read_csv('Car_2000_2250.csv')
df_2250_2500 = pd.read_csv('Car_2250_2500.csv')
df_2500_3000 = pd.read_csv('Car_2500_3000.csv')
df_3000_3500 = pd.read_csv('Car_3000_3500.csv')
df_3500_3738 = pd.read_csv('Car_3500_3738.csv')
df_6000_7000 = pd.read_csv('Car_6000_7000.csv')
df_7000_8000 = pd.read_csv('Car_7000_8000.csv')

combined_df = pd.concat([df_1_500, df_1_500Arlan, df_500_1000, 
                         df_500_1260Arlan, df_1000_1250, df_1250_2000, df_2000_2250, df_2250_2500, df_2500_3000, df_3000_3500, df_3500_3738,
                        df_6000_7000, df_7000_8000])
print(combined_df.shape)
combined_df = combined_df.drop_duplicates()
print(combined_df.shape)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_file.csv', index=False)
# Out:
# (6390, 13)
# (6342, 13)

# %%
df_1_500dima = pd.read_csv('Car_1_500dima.csv')
df_500_1000dima = pd.read_csv('Car_500_1000dima.csv')
df_1300_2300Arlan = pd.read_csv('Car_1300-2300Arlan.csv')
combined_df = pd.read_csv('combined_file.csv')
combined_df = pd.concat([df_1_500dima, df_500_1000dima, df_1300_2300Arlan, combined_df])
print(combined_df.shape)
combined_df = combined_df.drop_duplicates()
print(combined_df.shape)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_file2.csv', index=False)
# Out:
# (8341, 13)
# (8336, 13)

# %%
df_8000_8300 = pd.read_csv('Car_8000_8300.csv')
df_3739_5300 = pd.read_csv('Car_3739_5300.csv')
df_2300_2500Arlan = pd.read_csv('Car_2300_2500Arlan.csv')
df_2500_3000Arlan = pd.read_csv('Car_2500_3000Arlan.csv')
combined_df = pd.read_csv('combined_file2.csv')
combined_df = pd.concat([df_8000_8300, df_3739_5300, df_2300_2500Arlan, df_2500_3000Arlan, combined_df])
print(combined_df.shape)
combined_df = combined_df.drop_duplicates()
print(combined_df.shape)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_file3.csv', index=False)
# Out:
# (10807, 13)
# (10582, 13)

# %%
df_8300_10884 = pd.read_csv('Car_8300_10884.csv')
df_5300_6000 = pd.read_csv('Car_5300_6000.csv')
combined_df = pd.read_csv('combined_file3.csv')
combined_df = pd.concat([df_8300_10884, df_5300_6000, combined_df])
print(combined_df.shape)
combined_df = combined_df.drop_duplicates()
print(combined_df.shape)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_file4_so_far_Imash_final.csv', index=False)
# Out:
# (13800, 13)
# (13762, 13)

# %%
df_new_1_800 = pd.read_csv('Car_new_1_800.csv')
df_new_800_2200 = pd.read_csv('Car_new_800_2200.csv')
df_new_2200_3500 = pd.read_csv('Car_new_2200_3500.csv')
df_1000_2000dima = pd.read_csv('Car_1000_2000dima.csv')
df_2000_3000dima = pd.read_csv('Car_2000_3000dima.csv')
df_3000_5000dima = pd.read_csv('Car_3000_5000dima.csv')
df_5000_7000dima = pd.read_csv('Car_5000_7000dima.csv')
df_7000_10000dima = pd.read_csv('Car_7000_10000dima.csv')
df_3000_4000Arlan = pd.read_csv('Car_3000-4000Arlan.csv')
df_4000_4500Arlan = pd.read_csv('Car_4000-4500Arlan.csv')
df_4500_5500Arlan = pd.read_csv('Car_4500-5500Arlan.csv')
df_5500_6000Arlan = pd.read_csv('Car_5500-6000Arlan.csv')
df_6000_6500Arlan = pd.read_csv('Car_6000-6500Arlan.csv')
df_6500_7000Arlan = pd.read_csv('Car_6500-7000Arlan.csv')
df_7000_8000Arlan = pd.read_csv('Car_7000-8000Arlan.csv')
df_8000_10000Arlan = pd.read_csv('Car_8000_10000Arlan.csv')

combined_df = pd.read_csv('combined_file4_so_far_Imash_final.csv')
combined_df = pd.concat([df_new_1_800, df_new_800_2200, df_new_2200_3500, df_1000_2000dima, df_2000_3000dima, df_3000_5000dima, df_5000_7000dima,
                         df_7000_10000dima, df_3000_4000Arlan, df_4000_4500Arlan, df_4500_5500Arlan, df_5500_6000Arlan, df_6000_6500Arlan, 
                         df_6500_7000Arlan, df_7000_8000Arlan, df_8000_10000Arlan, 
                         combined_df])
print(combined_df.shape)
combined_df = combined_df.drop_duplicates()
print(combined_df.shape)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_file_final_ver.csv', index=False)
# Out:
# (32642, 13)
# (32225, 13)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ***Calling the dataset***

# %%
df = pd.read_csv('combined_file_final_ver.csv')
df
# Out:
#             Brand                 Name     Price  Year    City   Car case  \
# 0             Kia             Sportage   8580000  2013  Алматы  кроссовер
# 1          Toyota                RAV 4  13060000  2017  Алматы  кроссовер
# 2             BYD                 Seal  14250000  2023  Алматы      седан
# 3         Changan                UNI-K  14500000  2023  Алматы  кроссовер
# 4         Hyundai               Sonata  26000000  2022  Алматы      седан
# ...           ...                  ...       ...   ...     ...        ...
# 32220       Mazda                 CX-7   4000000  2006  Алматы  кроссовер
# 32221     Hyundai               Accent   7612049  2021  Алматы      седан
# 32222     Hyundai              Elantra   7800000  2018  Алматы      седан
# 32223       Volvo                  S80   5450000  2007  Алматы      седан
# 32224  ВАЗ (Lada)  Priora 2170 (седан)   3400000  2014  Алматы      седан
#
#        Volume Transmission   Mileage             Gear Steer wheel  \
# 0         2.0      автомат  218514.0  передний привод       слева
# 1         2.0     вариатор   72869.0  передний привод       слева
# 2         NaN      автомат       NaN    задний привод       слева
# 3         1.5        робот       NaN  передний привод       слева
# 4         2.5      автомат   70000.0  передний привод       слева
# ...       ...          ...       ...              ...         ...
# 32220     2.3      автомат  233000.0  передний привод       слева
# 32221     1.4     механика   58600.0  передний привод       слева
# 32222     2.0      автомат   40225.0  передний привод       слева
# 32223     2.5      автомат  180000.0  передний привод       слева
# 32224     1.6     механика  151000.0  передний привод       слева
#
#                  Color Custom clearance
# 0                белый               Да
# 1               черный               Да
# 2                белый               Да
# 3                серый              Нет
# 4       серый металлик               Да
# ...                ...              ...
# 32220              NaN               Да
# 32221            белый               Да
# 32222   серый металлик               Да
# 32223   серый металлик               Да
# 32224  черный металлик               Да
#
# [32225 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32225 entries, 0 to 32224
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             32225 non-null  object
#  1   Name              32216 non-null  object
#  2   Price             32225 non-null  int64
#  3   Year              32225 non-null  int64
#  4   City              32225 non-null  object
#  5   Car case          32220 non-null  object
#  6   Volume            31354 non-null  float64
#  7   Transmission      32217 non-null  object
#  8   Mileage           22696 non-null  float64
#  9   Gear              32214 non-null  object
#  10  Steer wheel       32225 non-null  object
#  11  Color             27188 non-null  object
#  12  Custom clearance  32225 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 3.2+ MB

# %% [markdown]
# ***Dealing with outliears***

# %%
df.describe()
# Out:
#               Price          Year        Volume        Mileage
# count  3.222500e+04  32225.000000  31354.000000   22696.000000
# mean   1.153425e+07   2010.252537      2.479377  146807.455499
# std    1.524484e+07     10.107811      0.967219  128411.310773
# min    1.000000e+04   1950.000000      0.300000       1.000000
# 25%    3.400000e+06   2003.000000      1.800000   40518.750000
# 50%    7.300000e+06   2012.000000      2.400000  123000.000000
# 75%    1.430000e+07   2020.000000      3.000000  220000.000000
# max    9.000000e+08   2023.000000      8.200000  999999.000000

# %%
cat_col = ['Year', 'Price', 'Mileage', 'Volume']
for col in cat_col:
    plt.subplots(figsize=(18,6))
    plt.title("Outliers visualization")
    df.boxplot(column=col, return_type='axes')

# %% [markdown]
# ***After exploring outliers information we drop the certain amount of rows***

# %%
#Since Year and Price columns have no missing values we use the following procedure
df = df[(df.Year > 1980)]
df = df[(df.Price < 50000000)]

# %%
#Volume and Mileage columns have a huge number of missing values, then we drop them by obtaining indexes***
df = df.drop(df[(df['Volume'] > 4.8)].index)
df = df.drop(df[(df['Mileage'] > 470000)].index)

# %%
#Checking the info about dataframe after above operations
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30078 entries, 0 to 32224
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             30078 non-null  object
#  1   Name              30069 non-null  object
#  2   Price             30078 non-null  int64
#  3   Year              30078 non-null  int64
#  4   City              30078 non-null  object
#  5   Car case          30076 non-null  object
#  6   Volume            29270 non-null  float64
#  7   Transmission      30070 non-null  object
#  8   Mileage           21014 non-null  float64
#  9   Gear              30067 non-null  object
#  10  Steer wheel       30078 non-null  object
#  11  Color             25373 non-null  object
#  12  Custom clearance  30078 non-null  object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 3.2+ MB

# %% [markdown]
# ***Printing the number of Null values of each column***

# %%
df.isnull().sum()
# Out:
# Brand                  0
# Name                   9
# Price                  0
# Year                   0
# City                   0
# Car case               2
# Volume               808
# Transmission           8
# Mileage             9064
# Gear                  11
# Steer wheel            0
# Color               4705
# Custom clearance       0
# dtype: int64

# %% [markdown]
# ***Plotting the histogramms for each object and numerical type column***

# %%
import pandas as pd

# Define the columns and their data types
columns = ['Column1', 'Column2', 'Column3']
data_types = [int, float, str]  # Specify the data types for each column

# Create an empty DataFrame with the specified columns and data types
empty_df = pd.DataFrame(columns=columns)

# Set the data types for the columns
for col, data_type in zip(columns, data_types):
    empty_df[col] = empty_df[col].astype(data_type)

# Display the empty DataFrame
print(empty_df)
# Out:
# Empty DataFrame
# Columns: [Column1, Column2, Column3]
# Index: []

# %%
name_l = df['Name'].unique()
for i in name_l:
    df1 = df[df['Name'] == i]
    if df1.shape[0] <= 5:
        empty_df = pd.concat([df1], axis=1)

# %%
plt.hist(empty_df['Price'], bins=20)  # Adjust the number of bins as needed
plt.title('Histogram of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
for column_name in df.columns:
    if df[column_name].dtype == 'object':
        plt.figure(figsize=(20, 8))  
        sns.countplot(x=column_name, data=df)
        plt.title(f'Count of {column_name}')
        plt.xticks(rotation=90) 
        plt.show()

# %%
for column_name in df.columns:
    if df[column_name].dtype == 'object':
        plt.figure(figsize=(20, 8))  
        sns.countplot(x=column_name, data=df)
        plt.title(f'Count of {column_name}')
        plt.xticks(rotation=90) 
        plt.show()

# %%
for column_name in df.columns:
    if df[column_name].dtype in ['int64', 'float64']:  # Check if it's a numerical column
        plt.hist(df[column_name], bins=20)  # Adjust the number of bins as needed
        plt.title(f'Histogram of {column_name}')
        plt.xlabel(column_name)
        plt.ylabel('Frequency')
        plt.show()

# %% [markdown]
# ***Droping specific columns after analyzing the above graphs***

# %%
df = df.drop(columns=['City', 'Custom clearance', 'Steer wheel'], axis=1)

# %% [markdown]
# ***Printing the rows where value in Name column is NaN***

# %%
null_names = df[df['Name'].isna()]
null_names
# Out:
#                Brand Name     Price  Year     Car case  Volume Transmission  \
# 14467  Mercedes-Benz  NaN   6000000  1997        седан     3.2      автомат
# 17627     ВАЗ (Lada)  NaN   4800000  2019        седан     1.6        робот
# 17717          Smart  NaN   3300000  2004      хэтчбек     1.3     механика
# 20137            BYD  NaN  16900000  2023    кроссовер     NaN      автомат
# 20715     Volkswagen  NaN  48999999  2023      минивэн     2.0        робот
# 22210     ВАЗ (Lada)  NaN   1550000  2010      хэтчбек     1.6     механика
# 24006     ВАЗ (Lada)  NaN   1100000  2012      хэтчбек     1.4     механика
# 25490            Kia  NaN   1200000  1998  внедорожник     2.0     механика
# 25959            BMW  NaN  10000000  2012        седан     3.0      автомат
#
#         Mileage             Gear             Color
# 14467  430000.0    задний привод   черный металлик
# 17627   70000.0  передний привод             белый
# 17717  225000.0  передний привод  зеленый металлик
# 20137      50.0  передний привод    белый металлик
# 20715    4000.0    полный привод    синий металлик
# 22210  179000.0  передний привод    серый металлик
# 24006  140000.0  передний привод               NaN
# 25490       NaN    полный привод               NaN
# 25959  120000.0    задний привод             белый

# %% [markdown]
# ***Dropping above rows***

# %%
df.dropna(subset=['Name'], inplace=True)
df.isna().sum()
# Out:
# Brand              0
# Name               0
# Price              0
# Year               0
# Car case           2
# Volume           807
# Transmission       8
# Mileage         9063
# Gear              11
# Color           4703
# dtype: int64

# %% [markdown]
# ***Filling the missing values***

# %%
columns_to_fill = ['Car case', 'Transmission', 'Gear', 'Color']
for column in columns_to_fill:
    mode_value = df[column].mode()[0]  # Calculate the mode of the column
    df[column].fillna(mode_value, inplace=True)
df.isna().sum()
# Out:
# Brand              0
# Name               0
# Price              0
# Year               0
# Car case           0
# Volume           807
# Transmission       0
# Mileage         9063
# Gear               0
# Color              0
# dtype: int64

# %%
df.loc[df['Year'] == 2023, 'Mileage'] = 0

mean_mileage = df['Mileage'].mean()
df['Mileage'].fillna(mean_mileage, inplace=True)
df.isna().sum()
# Out:
# Brand             0
# Name              0
# Price             0
# Year              0
# Car case          0
# Volume          807
# Transmission      0
# Mileage           0
# Gear              0
# Color             0
# dtype: int64

# %%
null_names = df[df['Volume'].isna()]
null_names['Name'].unique()
# Out:
# array(['Seal', 'EQC', '001', 'iX3', 'Han', 'LS7', 'X', 'Free', 'ID.4',
#        'Model Y', 'i3', 'e-Bora', 'G9', 'bZ4X', 'CR-V',
#        'Land Cruiser Prado', 'Leaf', 'e:NS1', 'Carina E', 'Benben E-Star',
#        'Model 3', 'Tang', 'ID.6', 'Dream', 'M-NV', 'Model X', 'Song',
#        'Yuan', 'E2', 'Ariya', 'Astra', '11', 'Taycan', 'F200',
#        'e-tron Sportback', 'e:NP1', 'W6', 'Granvia', 'i4', '009',
#        'Model S', 'GT', 'E-HS9', 'Z', 'Qin', 'Seagull', 'Aion Y', 'Y',
#        'Q2L e-tron', 'EV6', 'Dolphin', 'RZ 450e', 'C11', 'e-tron', 'EQE',
#        'iX', 'EQE SUV', 'I-Pace', 'EU5', 'Song Plus Champion', 'Kona',
#        'GV60', 'e-Lavida', 'ES3', 'Lyriq', 'N7', 'D9', 'P7', 'ID.3',
#        'Chasing Light', 'Q4 e-tron', 'U', 'Bongo', 'Space Wagon', 'V',
#        'Twizy', 'Airtrek', '#1', 'Menlo', 'M5 EV', 'Hongguang Mini EV',
#        'Golf', '323'], dtype=object)

# %%
petrol_cars = ['Land Cruiser Prado', 'Carina E', 'Kona', '323', 'Space Wagon', 'Golf', 'GT', 'CR-V']
electric_cars = [x for x in null_names['Name'].unique() if x not in petrol_cars]
len(electric_cars)
# Out:
# 75

# %%
# Replace NA values in the 'Volume' column based on car type
df['Volume'] = np.where(df['Name'].isin(electric_cars), 0, df['Volume'].fillna(df['Volume'].mean()))
df.isna().sum()
# Out:
# Brand           0
# Name            0
# Price           0
# Year            0
# Car case        0
# Volume          0
# Transmission    0
# Mileage         0
# Gear            0
# Color           0
# dtype: int64

# %%
#We save the dataframe after data preprocessing, we do it for futher application in Tkinter block
df.to_csv('data_preprop.csv', index=False)

# %% [markdown]
# ***Label encoder***

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}  # Store label encoders for each object-type column

# Preprocess your training data
for col in df.select_dtypes(include = ['object']).columns:
    label_encoders[col] = LabelEncoder()
    df[col] = label_encoders[col].fit_transform(df[col])
df
# Out:
#        Brand  Name     Price  Year  Car case  Volume  Transmission   Mileage  \
# 0         56   981   8580000  2013         2     2.0             0  218514.0
# 1        101   854  13060000  2017         2     2.0             1   72869.0
# 2          9   945  14250000  2023        10     0.0             0       0.0
# 3         13  1069  14500000  2023         2     1.5             3       0.0
# 4         44   969  26000000  2022        10     2.5             0   70000.0
# ...      ...   ...       ...   ...       ...     ...           ...       ...
# 32220     69   249   4000000  2006         2     2.3             0  233000.0
# 32221     44   142   7612049  2021        10     1.4             2   58600.0
# 32222     44   399   7800000  2018        10     2.0             0   40225.0
# 32223    103   917   5450000  2007        10     2.5             0  180000.0
# 32224    110   816   3400000  2014        10     1.6             2  151000.0
#
#        Gear  Color
# 0         1      2
# 1         1     40
# 2         0      2
# 3         1     30
# 4         1     31
# ...     ...    ...
# 32220     1      2
# 32221     1      2
# 32222     1     31
# 32223     1     31
# 32224     1     41
#
# [30069 rows x 10 columns]

# %% [markdown]
# ***Dividing the dataset into target and feature datasets***

# %%
Y = df['Price']
X = df.drop('Price', axis=1)
X
# Out:
#        Brand  Name  Year  Car case  Volume  Transmission   Mileage  Gear  \
# 0         56   981  2013         2     2.0             0  218514.0     1
# 1        101   854  2017         2     2.0             1   72869.0     1
# 2          9   945  2023        10     0.0             0       0.0     0
# 3         13  1069  2023         2     1.5             3       0.0     1
# 4         44   969  2022        10     2.5             0   70000.0     1
# ...      ...   ...   ...       ...     ...           ...       ...   ...
# 32220     69   249  2006         2     2.3             0  233000.0     1
# 32221     44   142  2021        10     1.4             2   58600.0     1
# 32222     44   399  2018        10     2.0             0   40225.0     1
# 32223    103   917  2007        10     2.5             0  180000.0     1
# 32224    110   816  2014        10     1.6             2  151000.0     1
#
#        Color
# 0          2
# 1         40
# 2          2
# 3         30
# 4         31
# ...      ...
# 32220      2
# 32221      2
# 32222     31
# 32223     31
# 32224     41
#
# [30069 rows x 9 columns]

# %% [markdown]
# ***Feature scaling***

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-0.50238908,  1.21243069,  0.28006064, ...,  0.86375599,
#         -0.35612614, -1.08605498],
#        [ 0.90182401,  0.83534762,  0.68199575, ..., -0.61704276,
#         -0.35612614,  1.35830034],
#        [-1.96901164,  1.105541  ,  1.28489841, ..., -1.35791491,
#         -1.88523608, -1.08605498],
#        ...,
#        [-0.8768459 , -0.51561929,  0.78247953, ..., -0.94894014,
#         -0.35612614,  0.77937408],
#        [ 0.96423348,  1.02240458, -0.32284202, ...,  0.47217727,
#         -0.35612614,  0.77937408],
#        [ 1.18266663,  0.72251961,  0.38054442, ...,  0.17732908,
#         -0.35612614,  1.42262548]])

# %% [markdown]
# ***Obtaining train and test datasets***

# %%
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y, test_size=0.3, random_state=42)
X_train
# Out:
# array([[ 1.52910364e-01,  4.16696336e-01, -1.22719602e+00, ...,
#         -2.95903846e-16, -3.56126140e-01, -1.08605498e+00],
#        [ 1.18266663e+00, -1.59639282e+00,  1.79576864e-01, ...,
#         -2.95903846e-16, -3.56126140e-01,  1.35830034e+00],
#        [ 5.92961579e-02,  6.30475715e-01, -3.22842022e-01, ...,
#          1.48889514e+00,  1.17298380e+00, -1.08605498e+00],
#        ...,
#        [ 9.01824014e-01,  2.20731904e-01, -2.22358244e-01, ...,
#         -2.95903846e-16,  1.17298380e+00,  1.35830034e+00],
#        [-6.55227837e-02, -3.28562336e-01, -1.42816357e+00, ...,
#         -3.41197032e-01,  1.17298380e+00,  1.42262548e+00],
#        [-4.39979609e-01,  8.94730782e-01,  5.81511973e-01, ...,
#         -5.85209322e-01,  1.17298380e+00, -1.08605498e+00]])

# %% [markdown]
# # Model implementation

# %% [markdown]
# ***Linear Regression Model***

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

model_lr = LinearRegression()
model_lr.fit(X_train, y_train)

# Make predictions on the test data
y_pred_lr = model_lr.predict(X_test)

# Calculate the model's accuracy using metrics like Mean Squared Error (MSE) and R-squared (R2)
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)

print(f"Mean Squared Error (MSE) for Linear Regression Model: {mse_lr}")
print(f"R-squared (R2) Score for Linear Regression Model: {r2_lr}")
# Out:
# Mean Squared Error (MSE) for Linear Regression Model: 28442796887482.27
# R-squared (R2) Score for Linear Regression Model: 0.6187554205130963

# %% [markdown]
# ***Decision Tree Classifier Model***

# %%
from sklearn.tree import DecisionTreeClassifier

clf_dt = DecisionTreeClassifier()

# Train the model on the training data
clf_dt.fit(X_train, y_train)

# Make predictions on the test data
y_pred_dt = clf_dt.predict(X_test)

# Evaluate the model
print(f"R-squared (R2) Score for Decision Tree Classifier Model: {r2_score(y_test, y_pred_dt)}")
# Out:
# R-squared (R2) Score for Decision Tree Classifier Model: 0.8533857296761722

# %% [markdown]
# ***k-Nearest Neighbors (K-NN) model***

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a K-NN Classifier with a specified number of neighbors (k)
k = 5  # You can adjust the value of k
clf_knn = KNeighborsClassifier(n_neighbors=k)

# Train the model on the training data
clf_knn.fit(X_train, y_train)

# Make predictions on the test data
y_pred_knn = clf_knn.predict(X_test)

# Evaluate the model
print(f"R-squared (R2) Score for K-NN Model: {r2_score(y_test, y_pred_knn)}")
# Out:
# R-squared (R2) Score for K-NN Model: 0.7614284196577826

# %% [markdown]
# # Application

# %%
import tkinter as tk
from tkinter import messagebox
from unidecode import unidecode

data = pd.read_csv('data_preprop.csv')
def predict_price():
    # Get user inputs
    brand = brand_entry.get()
    name = name_entry.get()

    if not brand or not name:
        messagebox.showerror("Error", "Both 'Brand' and 'Name' labels must be filled.")
        return

    user_input = {
        'Brand': brand,
        'Name': name,
        'Year': float(year_entry.get() or data['Year'].mean()),
        'Car case': car_case_entry.get() or data['Car case'].mode()[0],
        'Volume': float(volume_entry.get() or data['Volume'].mean()),
        'Transmission': transmission_entry.get() or data['Transmission'].mode()[0],
        'Mileage': float(mileage_entry.get() or data['Mileage'].mean()),
        'Gear': gear_entry.get()or data['Gear'].mode()[0],
        'Color': color_entry.get() or data['Color'].mode()[0]
    }
    
    # Encode user input using label encoders
    categorical_cols = ['Brand', 'Name', 'Car case', 'Transmission', 'Gear', 'Color']
    for col in categorical_cols: 
        if user_input[col] in label_encoders[col].classes_:
            user_input[col] = label_encoders[col].transform([user_input[col]])[0]
    
    # Create a DataFrame from user input
    user_data = pd.DataFrame([user_input])
    user_data = scaler.transform(user_data)
    # Make a price prediction
    predicted_price_lr = model_lr.predict(user_data)[0]
    predicted_price_dt = clf_dt.predict(user_data)[0]
    predicted_price_knn = clf_knn.predict(user_data)[0]

    # Display the predicted price
    result_label1.config(text=f"Predicted Price by Linear Regression: {predicted_price_lr:,.0f}".replace(',', ' ') + " ₸")
    result_label2.config(text=f"Predicted Price by Decision Tree: {predicted_price_dt:,.0f}".replace(',', ' ') + " ₸")
    result_label3.config(text=f"Predicted Price by K-NN: {predicted_price_knn:,.0f}".replace(',', ' ') + " ₸")

# Create a Tkinter window
window = tk.Tk()
window.title("Car Price Prediction")
window.geometry('500x500')
font = ("arial", 20, "bold")

# Convert the Pillow image to a PhotoImage
photo = tk.PhotoImage(file = "koleso logo.png")
photolabel = tk.Label(window, image=photo)
photolabel.place(x = 300, y = 300)

# Create labels and entry fields for user input
brand_label = tk.Label(window, text="Brand:")
name_label = tk.Label(window, text="Name:")
year_label = tk.Label(window, text="Year:")
car_case_label = tk.Label(window, text="Car case:")
volume_label = tk.Label(window, text="Volume:")
transmission_label = tk.Label(window, text="Transmission:")
mileage_label = tk.Label(window, text="Mileage:")
gear_label = tk.Label(window, text="Gear:")
steer_wheel_label = tk.Label(window, text="Steer wheel:")
color_label = tk.Label(window, text="Color")

brand_entry = tk.Entry(window)
name_entry = tk.Entry(window)
year_entry = tk.Entry(window)
car_case_entry = tk.Entry(window)
volume_entry = tk.Entry(window)
transmission_entry = tk.Entry(window)
mileage_entry = tk.Entry(window)
gear_entry = tk.Entry(window)
steer_wheel_entry = tk.Entry(window)
color_entry = tk.Entry(window)

predict_button = tk.Button(window, text="Predict Price", command=predict_price)
result_label1 = tk.Label(window, text="Predicted Price:")
result_label2 = tk.Label(window)
result_label3 = tk.Label(window)

# Arrange labels and entry fields in the window
brand_label.grid(row=0, column=0)
name_label.grid(row=1, column=0)
year_label.grid(row=2, column=0)
car_case_label.grid(row=3, column=0)
volume_label.grid(row=4, column=0)
transmission_label.grid(row=5, column=0)
mileage_label.grid(row=6, column=0)
gear_label.grid(row=7, column=0)
color_label.grid(row=9, column=0)

brand_entry.grid(row=0, column=1)
name_entry.grid(row=1, column=1)
year_entry.grid(row=2, column=1)
car_case_entry.grid(row=3, column=1)
volume_entry.grid(row=4, column=1)
transmission_entry.grid(row=5, column=1)
mileage_entry.grid(row=6, column=1)
gear_entry.grid(row=7, column=1)
color_entry.grid(row=9, column=1)

predict_button.grid(row=10, column=1, columnspan=5)
result_label1.grid(row=11, column=1, columnspan=5)
result_label2.grid(row=12, column=1, columnspan=5)
result_label3.grid(row=13, column=1, columnspan=5)

# Start the Tkinter main loop
window.mainloop()
